# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=200, centers=3, n_features=2, random_state=42)

print(X.shape)
# Out:
# (200, 2)

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

data = {
    "Feature1": np.round(np.random.uniform(5.0, 9.0, 200), 2),  
    "Feature2": np.random.randint(90, 120, 200)                  
}

df = pd.DataFrame(data)
print(df.head())
df.to_csv("kmeans_practice.csv", index=True)
# Out:
#    Feature1  Feature2
# 0      6.50       113
# 1      8.80       109
# 2      7.93       100
# 3      7.39       106
# 4      5.62        97

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Feature1'] , df['Feature2'])

# %%
from sklearn.cluster import KMeans

# %%
wcss = []

for i in range(1,11):
    km  = KMeans(n_clusters = i)
    km.fit_predict(df)
    wcss.append(km.inertia_)

# %%
wcss
# Out:
# [16499.002238,
#  4288.498320716113,
#  1918.8617878030548,
#  1213.7805617345227,
#  825.7056615637531,
#  667.2603921626069,
#  550.850421735545,
#  509.1464772165233,
#  422.08331155058363,
#  429.1577022395168]

# %%
plt.plot(range(1,11),wcss)

# %%
X = df.iloc[:,:].values
km = KMeans(n_clusters=5)
y_means = km.fit_predict(X)

# %%
X[y_means == 1]
# Out:
# array([[ 5.62, 93.  ],
#        [ 5.23, 95.  ],
#        [ 5.08, 92.  ],
#        [ 5.73, 92.  ],
#        [ 7.45, 91.  ],
#        [ 6.17, 92.  ],
#        [ 5.8 , 93.  ],
#        [ 7.06, 90.  ],
#        [ 7.37, 93.  ],
#        [ 5.19, 90.  ],
#        [ 5.39, 92.  ],
#        [ 6.76, 90.  ],
#        [ 5.74, 95.  ],
#        [ 8.88, 95.  ],
#        [ 5.78, 91.  ],
#        [ 6.55, 90.  ],
#        [ 6.43, 90.  ],
#        [ 6.12, 94.  ],
#        [ 8.95, 93.  ],
#        [ 8.09, 92.  ],
#        [ 5.46, 95.  ],
#        [ 8.45, 92.  ],
#        [ 5.25, 94.  ],
#        [ 6.89, 92.  ],
#        [ 7.85, 90.  ],
#        [ 7.09, 90.  ],
#        [ 6.71, 92.  ],
#        [ 7.03, 92.  ],
#        [ 5.64, 91.  ],
#        [ 7.53, 91.  ],
#        [ 8.57, 90.  ],
#        [ 5.03, 92.  ],
#        [ 7.81, 93.  ],
#        [ 8.85, 90.  ],
#        [ 8.63, 91.  ],
#        [ 5.96, 91.  ],
#        [ 6.28, 95.  ],
#        [ 5.07, 94.  ],
#        [ 7.05, 90.  ],
#        [ 8.75, 94.  ],
#        [ 6.36, 93.  ],
#        [ 5.45, 95.  ],
#        [ 8.27, 92.  ]])

# %%
plt.scatter(X[y_means == 0,0],X[y_means == 0,1],color='blue')
plt.scatter(X[y_means == 1,0],X[y_means == 1,1],color='red')
plt.scatter(X[y_means == 2,0],X[y_means == 2,1],color='green')
plt.scatter(X[y_means == 3,0],X[y_means == 3,1],color='yellow')
